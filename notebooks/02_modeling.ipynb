# %%
import pandas as pd

df = pd.read_csv("data/macro_data_clean.csv")

print(df.head())
# Out:
#    Unnamed: 0  yield curve spread  unemployment rate  CPI inflation  \
# 0  1980-01-31           -0.695909                6.3           78.0
# 1  1980-02-29           -1.003684                6.3           79.0
# 2  1980-03-31           -2.135714                6.3           80.1
# 3  1980-04-30           -1.028571                6.9           80.9
# 4  1980-05-31            0.731429                7.5           81.7
#
#    GDP growth  consumer confidence  fed funds rate  recession indicator
# 0         1.3                 67.0           13.82                  0.0
# 1         1.3                 66.9           14.13                  1.0
# 2         1.3                 56.5           17.19                  1.0
# 3        -8.0                 52.7           17.61                  1.0
# 4        -8.0                 51.7           10.98                  1.0
